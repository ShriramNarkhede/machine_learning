# %% [markdown]
# Pandas Day 2

# %%
import pandas as pd

# %%
df=pd.read_csv("dog.csv")

# %%
df.head()
# Out:
#    HALTER_ID  ALTER GESCHLECHT  STADTKREIS  STADTQUARTIER              RASSE1  \
# 0        126  51-60          m         9.0           92.0       Welsh Terrier
# 1        574  61-70          w         2.0           23.0       Cairn Terrier
# 2        695  41-50          m         6.0           63.0  Labrador Retriever
# 3        893  61-70          w         7.0           71.0     Mittelschnauzer
# 4       1177  51-60          m        10.0          102.0            Shih Tzu
#
#   RASSE1_MISCHLING RASSE2  RASSE2_MISCHLING RASSENTYP  GEBURTSJAHR_HUND  \
# 0              NaN    NaN               NaN         K              2011
# 1              NaN    NaN               NaN         K              2002
# 2              NaN    NaN               NaN         I              2012
# 3              NaN    NaN               NaN         I              2010
# 4              NaN    NaN               NaN         K              2011
#
#   GESCHLECHT_HUND     HUNDEFARBE
# ...

# %%
df[df['STADTKREIS'] >= 7]
# Out:
#       HALTER_ID  ALTER GESCHLECHT  STADTKREIS  STADTQUARTIER  \
# 0           126  51-60          m         9.0           92.0
# 3           893  61-70          w         7.0           71.0
# 4          1177  51-60          m        10.0          102.0
# 6          4050  41-50          w        11.0          111.0
# 7          4155  61-70          w         9.0           92.0
# ...         ...    ...        ...         ...            ...
# 6973     128460  31-40          w         9.0           91.0
# 6975     128471  21-30          w         8.0           83.0
# 6976     128471  21-30          w         8.0           83.0
# 6978     128482  21-30          w         9.0           91.0
# 6979     128485  21-30          w         7.0           74.0
#
#                  RASSE1 RASSE1_MISCHLING RASSE2  RASSE2_MISCHLING RASSENTYP  \
# 0         Welsh Terrier              NaN    NaN               NaN         K
# 3       Mittelschnauzer              NaN    NaN               NaN         I
# ...

# %%
df[(df['GESCHLECHT'] == 'm') & (df['STADTKREIS'] >8)]
# Out:
#       HALTER_ID  ALTER GESCHLECHT  STADTKREIS  STADTQUARTIER  \
# 0           126  51-60          m         9.0           92.0
# 4          1177  51-60          m        10.0          102.0
# 26         5113  51-60          m        11.0          119.0
# 28         5227  61-70          m        10.0          101.0
# 34         6314  61-70          m        10.0          101.0
# ...         ...    ...        ...         ...            ...
# 6938     128258  31-40          m        12.0          122.0
# 6942     128311  31-40          m        11.0          119.0
# 6960     128412  41-50          m         9.0           91.0
# 6965     128442  21-30          m         9.0           92.0
# 6966     128444  61-70          m        11.0          119.0
#
#                    RASSE1 RASSE1_MISCHLING      RASSE2  RASSE2_MISCHLING  \
# 0           Welsh Terrier              NaN         NaN               NaN
# 4                Shih Tzu              NaN         NaN               NaN
# ...

# %%
df[df['GESCHLECHT'].isin(['m','w'])]
# Out:
#       HALTER_ID  ALTER GESCHLECHT  STADTKREIS  STADTQUARTIER  \
# 0           126  51-60          m         9.0           92.0
# 1           574  61-70          w         2.0           23.0
# 2           695  41-50          m         6.0           63.0
# 3           893  61-70          w         7.0           71.0
# 4          1177  51-60          m        10.0          102.0
# ...         ...    ...        ...         ...            ...
# 6975     128471  21-30          w         8.0           83.0
# 6976     128471  21-30          w         8.0           83.0
# 6977     128479  51-60          w         6.0           63.0
# 6978     128482  21-30          w         9.0           91.0
# 6979     128485  21-30          w         7.0           74.0
#
#                   RASSE1 RASSE1_MISCHLING RASSE2  RASSE2_MISCHLING RASSENTYP  \
# 0          Welsh Terrier              NaN    NaN               NaN         K
# ...

# %% [markdown]
# STRING

# %%
ds = pd.DataFrame({
    'Email': ['alice@gmail.com', 'bob@yahoo.com', 'carol@hotmail.com']
})

# Filter emails ending with 'gmail.com'
ds[ds['Email'].str.contains(r'yahoo\.com$', regex=True)]
# Out:
#            Email
# 1  bob@yahoo.com

# %%
df[df['RASSE1'].str.startswith('S')]
# Out:
#       HALTER_ID  ALTER GESCHLECHT  STADTKREIS  STADTQUARTIER  \
# 4          1177  51-60          m        10.0          102.0
# 22         4889  51-60          m         8.0           82.0
# 38         6594  51-60          m         7.0           72.0
# 41         6629  51-60          w         4.0           41.0
# 66        21828  71-80          w         7.0           74.0
# ...         ...    ...        ...         ...            ...
# 6911     128123  61-70          w        11.0          111.0
# 6925     128166  21-30          w         9.0           92.0
# 6927     128170  41-50          w         5.0           51.0
# 6931     128232  41-50          w         8.0           81.0
# 6937     128252  41-50          w         6.0           61.0
#
#                           RASSE1 RASSE1_MISCHLING         RASSE2  \
# 4                       Shih Tzu              NaN            NaN
# 22                     Shiba Inu              NaN            NaN
# ...

# %% [markdown]
# ✅ 2. Adding / Removing Columns

# %%
ds
# Out:
#                Email
# 0    alice@gmail.com
# 1      bob@yahoo.com
# 2  carol@hotmail.com

# %%
ds['name']=['alice','bob','carlo']

# %%
ds
# Out:
#                Email   name
# 0    alice@gmail.com  alice
# 1      bob@yahoo.com    bob
# 2  carol@hotmail.com  carlo

# %%
ds['weight']=[50,22,16]

# %%
ds
# Out:
#                Email   name  weight
# 0    alice@gmail.com  alice      50
# 1      bob@yahoo.com    bob      22
# 2  carol@hotmail.com  carlo      16

# %%
ds['lbs']=ds['weight'] * 2

# %%
ds['AgeCategory'] = ds['weight'].apply(lambda x: 'Adult' if x >= 18 else 'Child')

# %%
ds
# Out:
#                Email   name  weight AgeCategory
# 0    alice@gmail.com  alice      50       Adult
# 1      bob@yahoo.com    bob      22       Adult
# 2  carol@hotmail.com  carlo      16       Child

# %%
ds.rename(columns={'age' : 'Age'},inplace=True)

# %%
ds
# Out:
#                Email   name  Age  weight  lbs AgeCategory
# 0    alice@gmail.com  alice   50      50  100       Adult
# 1      bob@yahoo.com    bob   22      22   44       Adult
# 2  carol@hotmail.com  carlo   16      16   32       Child

# %% [markdown]
# Performing Math Operations on Columns

# %%
ds['AgeToWeightDiff']=ds['lbs']-ds['Age']

# %%
ds
# Out:
#                Email   name  Age  weight  lbs AgeCategory  AgeToWeightDiff
# 0    alice@gmail.com  alice   50      50  100       Adult               50
# 1      bob@yahoo.com    bob   22      22   44       Adult               22
# 2  carol@hotmail.com  carlo   16      16   32       Child               16
